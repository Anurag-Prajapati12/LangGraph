# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from typing import TypedDict

# %%
load_dotenv()
llm = ChatGoogleGenerativeAI(model = "models/gemini-2.5-flash")

# %%
# state creatiom
class BlogState(TypedDict):
    title: str
    outline: str
    blog: str

# %%
def create_outline(state: BlogState) -> BlogState:
    title = state['title']
    prompt = f"Generate an outline for a blog on the topic - {title}"
    state['outline'] = llm.invoke(prompt).content

    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    title = state['title']
    outline = state['outline']

    prompt = f"generate a detaiuled blog on the topic - {title}, using the following outline \n {outline}"

    state['blog'] = llm.invoke(prompt).content

    return state

# %%
# creating graph
graph = StateGraph(BlogState)

# creating node
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

# create edges
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

# compiling
workflow = graph.compile()

# %%
initial_state = {'title':'Rise of AI in India'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Okay, here\'s a comprehensive outline for a blog post on "The Rise of AI in India," designed to be engaging, informative, and well-structured.\n\n---\n\n**Blog Post Title Options:**\n*   The AI Awakening: How India is Becoming a Global Tech Powerhouse\n*   From Bangalore to Bharat: Charting the Rise of AI in India\n*   India\'s Intelligent Future: Unpacking the AI Revolution\n*   Beyond the Hype: Understanding India\'s Unique AI Journey\n\n**Target Audience:** Tech enthusiasts, business professionals, policymakers, students, and anyone interested in India\'s technological advancements.\n\n**Tone:** Optimistic, informative, analytical, forward-looking.\n\n---\n\n## Blog Outline: The Rise of AI in India\n\n**I. Introduction (Approx. 150-200 words)**\n\n*   **A. Engaging Hook:** Start with a striking statement about AI\'s omnipresence or a surprising statistic related to India\'s tech growth.\n    *   *Example: "While the world grapples with the implications of artificial intelligence, a quiet revolution has been brewing in the heart of Asia – India. Once known primarily for its IT services, India is rapidly transforming into a formidable player in the global AI landscape."*\n*   **B. Brief Definition of AI:** A concise, easy-to-understand explanation of what AI is (machine learning, deep learning, natural language processing).\n*   **C. Thesis Statement/Main Message:** India\'s unique blend of talent, data, government support, and pressing societal challenges has created a fertile ground for AI innovation, positioning it as a key global AI hub.\n*   **D. What the Blog Will Cover:** Briefly outline the key areas to be explored (drivers, applications, challenges, future).\n\n**II. The Catalysts: Why AI is Booming in India (Approx. 300-400 words)**\n\n*   **A. A Vast and Talented Workforce:**\n    *   Large pool of STEM graduates.\n    *   Strong English proficiency.\n    *   Growing expertise in data science, machine learning, and software development.\n*   **B. Government Initiatives & Policy Support:**\n    *   "Digital India" and "Make in India" campaigns.\n    *   NITI Aayog\'s "National Strategy for Artificial Intelligence" (#AIforAll).\n    *   Investments in AI research centers and skill development programs.\n    *   Focus on ethical and responsible AI.\n*   **C. Data Rich Environment:**\n    *   Massive population generating enormous amounts of data.\n    *   Rapid digitalization (UPI, Aadhaar, Jio revolution) leading to accessible datasets.\n    *   Diverse linguistic data for NLP advancements.\n*   **D. Thriving Startup Ecosystem & Investment:**\n    *   Increase in AI-focused startups (Bengaluru, Hyderabad, Gurugram).\n    *   Growing venture capital and private equity investment in AI.\n    *   Incubators and accelerators supporting AI innovation.\n*   **E. Problem-Solving Imperative:**\n    *   AI\'s potential to address large-scale Indian challenges (healthcare, agriculture, education, logistics).\n    *   Focus on affordable and scalable solutions.\n\n**III. AI in Action: Key Sectors Being Transformed (Approx. 400-500 words)**\n\n*   **A. Healthcare:**\n    *   Diagnostics (e.g., AI for early detection of diseases like retinopathy, cancer).\n    *   Drug discovery and personalized medicine.\n    *   Telemedicine and remote patient monitoring.\n    *   *Example: Aravind Eye Care\'s use of AI for diabetic retinopathy screening.*\n*   **B. Agriculture (AgriTech):**\n    *   Crop yield prediction and optimization.\n    *   Pest and disease detection.\n    *   Weather forecasting and precision farming.\n    *   *Example: Startups using satellite imagery and drones for farm analytics.*\n*   **C. Finance (FinTech):**\n    *   Fraud detection and risk assessment.\n    *   Personalized banking and investment advice.\n    *   Credit scoring for the unbanked/underbanked.\n    *   *Example: UPI\'s underlying AI for seamless transactions, lending apps.*\n*   **D. E-commerce & Retail: ...

# %%
print(final_state['outline'])
# Out:
# Okay, here's a comprehensive outline for a blog post on "The Rise of AI in India," designed to be engaging, informative, and well-structured.
#
# ---
#
# **Blog Post Title Options:**
# *   The AI Awakening: How India is Becoming a Global Tech Powerhouse
# *   From Bangalore to Bharat: Charting the Rise of AI in India
# *   India's Intelligent Future: Unpacking the AI Revolution
# *   Beyond the Hype: Understanding India's Unique AI Journey
#
# **Target Audience:** Tech enthusiasts, business professionals, policymakers, students, and anyone interested in India's technological advancements.
#
# **Tone:** Optimistic, informative, analytical, forward-looking.
#
# ---
#
# ## Blog Outline: The Rise of AI in India
#
# **I. Introduction (Approx. 150-200 words)**
#
# *   **A. Engaging Hook:** Start with a striking statement about AI's omnipresence or a surprising statistic related to India's tech growth.
#     *   *Example: "While the world grapples with the implications of artificial intelligence, a quiet revolution has been brewing in the heart of Asia – India. Once known primarily for its IT services, India is rapidly transforming into a formidable player in the global AI landscape."*
# *   **B. Brief Definition of AI:** A concise, easy-to-understand explanation of what AI is (machine learning, deep learning, natural language processing).
# *   **C. Thesis Statement/Main Message:** India's unique blend of talent, data, government support, and pressing societal challenges has created a fertile ground for AI innovation, positioning it as a key global AI hub.
# *   **D. What the Blog Will Cover:** Briefly outline the key areas to be explored (drivers, applications, challenges, future).
#
# **II. The Catalysts: Why AI is Booming in India (Approx. 300-400 words)**
#
# *   **A. A Vast and Talented Workforce:**
#     *   Large pool of STEM graduates.
#     *   Strong English proficiency.
#     *   Growing expertise in data science, machine learning, and software development.
# *   **B. Government Initiatives & Policy Support:**
#     *   "Digital India" and "Make in India" campaigns.
#     *   NITI Aayog's "National Strategy for Artificial Intelligence" (#AIforAll).
#     *   Investments in AI research centers and skill development programs.
#     *   Focus on ethical and responsible AI.
# *   **C. Data Rich Environment:**
#     *   Massive population generating enormous amounts of data.
#     *   Rapid digitalization (UPI, Aadhaar, Jio revolution) leading to accessible datasets.
#     *   Diverse linguistic data for NLP advancements.
# *   **D. Thriving Startup Ecosystem & Investment:**
#     *   Increase in AI-focused startups (Bengaluru, Hyderabad, Gurugram).
#     *   Growing venture capital and private equity investment in AI.
#     *   Incubators and accelerators supporting AI innovation.
# *   **E. Problem-Solving Imperative:**
#     *   AI's potential to address large-scale Indian challenges (healthcare, agriculture, education, logistics).
#     *   Focus on affordable and scalable solutions.
#
# **III. AI in Action: Key Sectors Being Transformed (Approx. 400-500 words)**
#
# *   **A. Healthcare:**
#     *   Diagnostics (e.g., AI for early detection of diseases like retinopathy, cancer).
#     *   Drug discovery and personalized medicine.
#     *   Telemedicine and remote patient monitoring.
#     *   *Example: Aravind Eye Care's use of AI for diabetic retinopathy screening.*
# *   **B. Agriculture (AgriTech):**
#     *   Crop yield prediction and optimization.
#     *   Pest and disease detection.
#     *   Weather forecasting and precision farming.
#     *   *Example: Startups using satellite imagery and drones for farm analytics.*
# *   **C. Finance (FinTech):**
#     *   Fraud detection and risk assessment.
#     *   Personalized banking and investment advice.
#     *   Credit scoring for the unbanked/underbanked.
#     *   *Example: UPI's underlying AI for seamless transactions, lending apps.*
# *   **D. E-commerce & Retail:**
#     *   Personalized recommendations and customer experience.
#     *   Supply chain optimization and logistics.
#     *   Chatbots for customer service.
# *   **E. Education (EdTech):**
#     *   Personalized learning paths and adaptive content.
#     *   Intelligent tutoring systems.
#     *   Automated assessment.
# *   **F. Smart Cities & Governance:**
#     *   Traffic management and urban planning.
#     *   Public safety and surveillance.
#     *   Grievance redressal systems.
#
# **IV. Opportunities and Challenges Ahead (Approx. 300-400 words)**
#
# *   **A. Opportunities:**
#     *   **Economic Growth:** Creation of new industries and jobs.
#     *   **Global Competitiveness:** India as an AI product and service exporter.
#     *   **Improved Quality of Life:** Better access to services, enhanced efficiency.
#     *   **Social Inclusion:** Bridging gaps in healthcare, education, and finance.
# *   **B. Challenges:**
#     *   **Data Privacy & Security:** Need for robust regulations and infrastructure.
#     *   **Ethical AI & Bias:** Ensuring fairness, transparency, and accountability, especially with diverse datasets.
#     *   **Job Displacement:** The need for reskilling and upskilling the workforce to adapt to automation.
#     *   **Infrastructure Gaps:** Ensuring equitable access to high-speed internet and computing power in rural areas.
#     *   **Skill Gap:** Bridging the gap between academic knowledge and industry demands in niche AI areas.
#     *   **Regulatory Framework:** Developing agile and effective policies to keep pace with rapid AI advancements.
#
# **V. The Road Ahead: India's AI Future (Approx. 150-200 words)**
#
# *   **A. Continued Innovation:** Expect more breakthroughs in specialized AI applications relevant to India.
# *   **B. Global Collaboration:** India's role in shaping global AI standards and ethics.
# *   **C. Democratization of AI:** Making AI tools and benefits accessible to a broader population.
# *   **D. Focus on Responsible AI:** Emphasizing ethical development and deployment to ensure equitable growth.
#
# **VI. Conclusion (Approx. 100-150 words)**
#
# *   **A. Recap Key Points:** Briefly reiterate India's unique position, the drivers of its AI growth, and the transformative impact.
# *   **B. Reiterate Thesis:** India's journey in AI is not just about technological advancement but about leveraging intelligence for inclusive growth and global leadership.
# *   **C. Call to Action/Final Thought:** Encourage readers to engage with India's AI story, support responsible innovation, or consider the broader implications.
#     *   *Example: "As India continues its intelligent ascent, the world watches with anticipation. The choices made today in policy, investment, and ethical development will define not just India's future, but potentially, the future of AI for all."*
#
# ---
#
# This outline provides a solid framework. Remember to use compelling storytelling, real-world examples, and clear, concise language throughout the blog post.

# %%
print(final_state['blog'])
# Out:
# ## India's Intelligent Future: Unpacking the AI Revolution
#
# While the world grapples with the myriad implications of artificial intelligence, a quiet, yet powerful revolution has been brewing in the heart of Asia – India. Once primarily recognized for its prowess in IT services, the nation is now rapidly transforming into a formidable player in the global AI landscape, poised to shape the future of intelligent technologies. At its core, Artificial Intelligence (AI) encompasses sophisticated technologies like machine learning, deep learning, and natural language processing, enabling machines to perceive, reason, learn, and act with human-like intelligence.
#
# India's unique blend of a vast talent pool, an abundance of data, proactive government support, and a pressing need to solve large-scale societal challenges has created an exceptionally fertile ground for AI innovation. This distinct ecosystem is positioning the country not just as a consumer, but as a crucial global AI hub. This blog post will delve into the powerful drivers behind India's AI boom, explore the diverse sectors AI is transforming, examine the opportunities and challenges on the horizon, and cast a gaze into the nation's intelligent future.
#
# ### The Catalysts: Why AI is Booming in India
#
# Several interconnected factors are fueling India's rapid ascent in the AI domain, creating a unique environment ripe for technological breakthrough.
#
# **A. A Vast and Talented Workforce:** India boasts one of the world's largest pools of STEM graduates, with a significant number specializing in computer science, engineering, and mathematics. This provides a constant influx of bright minds eager to delve into cutting-edge fields. Coupled with strong English proficiency, which facilitates global collaboration and access to international research, India has a growing expertise in data science, machine learning, and software development, essential building blocks for AI.
#
# **B. Government Initiatives & Policy Support:** The Indian government has recognized AI as a strategic imperative. Flagship programs like "Digital India" and "Make in India" have laid the groundwork for digital transformation, while NITI Aayog's "National Strategy for Artificial Intelligence" (#AIforAll) explicitly outlines a vision for leveraging AI for inclusive growth. This strategy focuses on five core sectors: healthcare, agriculture, education, smart cities, and infrastructure. Investments in AI research centers, skill development programs, and a growing emphasis on ethical and responsible AI development further underscore the government's commitment.
#
# **C. Data Rich Environment:** With a population exceeding 1.4 billion, India is a massive generator of diverse data. The rapid pace of digitalization, spearheaded by initiatives like the Unified Payments Interface (UPI) and Aadhaar, coupled with the "Jio revolution" that democratized internet access, has led to an explosion of accessible datasets. Furthermore, India's linguistic diversity provides an unparalleled opportunity for advancements in natural language processing (NLP) tailored to multiple local languages.
#
# **D. Thriving Startup Ecosystem & Investment:** Major urban centers like Bengaluru, Hyderabad, and Gurugram have emerged as bustling hubs for AI-focused startups. These innovative companies are attracting significant venture capital and private equity investment, reflecting growing confidence in India's AI potential. A network of incubators and accelerators further nurtures these nascent ventures, providing essential mentorship, funding, and infrastructure.
#
# **E. Problem-Solving Imperative:** Unlike many developed nations, India faces unique, large-scale challenges across various sectors. AI offers transformative potential to address these issues in healthcare, agriculture, education, logistics, and governance. This imperative drives a focus on developing affordable, scalable, and impactful AI solutions that can benefit millions, rather than just niche markets.
#
# ### AI in Action: Key Sectors Being Transformed
#
# The impact of AI is reverberating across numerous sectors in India, driving efficiency, accessibility, and innovation.
#
# **A. Healthcare:** AI is proving to be a game-changer in a country with vast healthcare disparities. It's revolutionizing diagnostics, enabling early and accurate detection of diseases. For instance, **Aravind Eye Care** leverages AI to screen for diabetic retinopathy, a leading cause of blindness, in rural areas, making specialized care accessible. AI also aids in drug discovery, personalized medicine tailored to individual genetic profiles, and enhances telemedicine and remote patient monitoring, extending medical reach to underserved populations.
#
# **B. Agriculture (AgriTech):** For an agrarian economy, AI offers unprecedented opportunities. Startups are using satellite imagery, drones, and machine learning to provide farmers with insights into crop yield prediction and optimization, precise pest and disease detection, and hyper-local weather forecasting. This "precision farming" approach helps minimize waste, improve productivity, and enhance farmers' livelihoods.
#
# **C. Finance (FinTech):** India's FinTech sector is rapidly adopting AI for enhanced security and personalized services. AI algorithms are crucial for real-time fraud detection and robust risk assessment. Personalized banking and investment advice are becoming standard, while AI-powered credit scoring models are extending financial services to the unbanked and underbanked, fostering greater financial inclusion. The success of **UPI** itself is underpinned by AI and machine learning, ensuring seamless and secure digital transactions.
#
# **D. E-commerce & Retail:** AI is at the heart of the personalized customer experience in India's booming e-commerce market. From intelligent product recommendations and dynamic pricing to optimizing complex supply chains and logistics, AI ensures efficiency. Chatbots powered by natural language processing provide instant customer service, enhancing satisfaction and operational scale.
#
# **E. Education (EdTech):** AI is personalizing learning on an unprecedented scale. Adaptive learning platforms create tailored educational paths, intelligent tutoring systems provide individualized support, and automated assessment tools free up educators' time, allowing them to focus on more complex pedagogical tasks. This is particularly vital in a country with a diverse student population and varying learning needs.
#
# **F. Smart Cities & Governance:** In India's rapidly urbanizing landscape, AI is instrumental in creating smarter, more efficient cities. It powers intelligent traffic management systems, optimizes urban planning, enhances public safety through advanced surveillance, and streamlines grievance redressal systems, making governance more responsive and citizen-centric.
#
# ### Opportunities and Challenges Ahead
#
# While the trajectory for AI in India is overwhelmingly positive, its path is not without significant opportunities and important hurdles.
#
# **A. Opportunities:**
# *   **Economic Growth:** AI is poised to create new industries, generate millions of high-skilled jobs, and significantly boost India's GDP, cementing its position as a global economic powerhouse.
# *   **Global Competitiveness:** By developing unique AI products and services tailored to emerging market needs, India can become a major exporter of AI solutions, enhancing its global technological standing.
# *   **Improved Quality of Life:** AI can dramatically improve access to essential services like healthcare and education, enhance urban living, and increase overall efficiency, directly impacting the quality of life for millions.
# *   **Social Inclusion:** Leveraging AI to bridge gaps in financial access, healthcare delivery, and educational opportunities can drive unprecedented social inclusion, reaching even the remotest parts of the country.
#
# **B. Challenges:**
# *   **Data Privacy & Security:** With vast amounts of personal data being processed, robust regulations, secure infrastructure, and strong public trust are paramount to prevent misuse and breaches.
# *   **Ethical AI & Bias:** Ensuring fairness, transparency, and accountability in AI systems is critical, especially given India's diverse socio-economic and cultural landscape. AI models must be trained on representative datasets to avoid perpetuating or amplifying existing biases.
# *   **Job Displacement:** The rise of automation through AI will inevitably lead to job displacement in certain sectors. A proactive approach to reskilling and upskilling the workforce is essential to prepare them for new roles and prevent widespread unemployment.
# *   **Infrastructure Gaps:** While digitalization is rapid, ensuring equitable access to high-speed internet and adequate computing power in rural and remote areas remains a challenge that could hinder widespread AI adoption.
# *   **Skill Gap:** Despite a large talent pool, a significant gap exists between academic knowledge and the niche, specialized demands of the AI industry, requiring targeted training and industry-academia collaboration.
# *   **Regulatory Framework:** The fast-evolving nature of AI necessitates an agile and effective regulatory framework that can keep pace with technological advancements while fostering innovation and ensuring ethical deployment.
#
# ### The Road Ahead: India's AI Future
#
# India's journey in AI is just beginning, but the momentum is undeniable. We can anticipate continued innovation, with more breakthroughs in specialized AI applications that are uniquely relevant to India's context and challenges. India is also poised to play an increasingly significant role in global collaboration, contributing to the development of international AI standards and ethical guidelines.
#
# A key focus will be the democratization of AI, ensuring that its tools and benefits are accessible to a broader population, not just the urban elite. This includes developing user-friendly interfaces and leveraging local languages. Crucially, India's AI future will be defined by its commitment to responsible AI – emphasizing ethical development and deployment to ensure that this powerful technology serves as a force for equitable growth and societal good.
#
# ### Conclusion
#
# India's rise in the AI domain is a testament to its unique strengths: a vibrant talent pool, a data-rich environment, visionary government support, and an unwavering drive to solve complex problems. The transformative impact of AI is already evident across healthcare, agriculture, finance, and beyond, promising a future of enhanced efficiency, accessibility, and innovation.
#
# India's journey in AI is not merely about technological advancement; it's about leveraging intelligence for inclusive growth, sustainable development, and global leadership. As India continues its intelligent ascent, the world watches with anticipation. The choices made today in policy, investment, and ethical development will define not just India's future, but potentially, the future of AI for all, setting a precedent for how a diverse nation can harness intelligence for the betterment of humanity.
